# %%
import gymnasium
from src.agent import TicTacToeAgent

# %%
env = gymnasium.make('TicTacToe-v0', depth=0)

agent = TicTacToeAgent(env)

agent.learn(25_000)
# Out:
# 100%|██████████| 25000/25000 [01:15<00:00, 333.12it/s]
